# %%
import numpy as np
import pandas as pd

# %%
rock = '../2.4-lab/assets/datasets/rock.csv'

df = pd.DataFrame(pd.read_csv(rock))

# %%
df
# Out:
#                                        Song Clean   ARTIST CLEAN Release Year  \
# 0                                Caught Up in You    .38 Special         1982
# 1                                    Fantasy Girl    .38 Special          NaN
# 2                                 Hold On Loosely    .38 Special         1981
# 3                          Rockin' Into the Night    .38 Special         1980
# 4                               Art For Arts Sake           10cc         1975
# 5                                      Kryptonite   3 Doors Down         2000
# 6                                           Loser   3 Doors Down         2000
# 7                                   When I'm Gone   3 Doors Down         2002
# 8                                      What's Up?  4 Non Blondes         1992
# 9                                      Take On Me           a-ha         1985
# 10                          Baby, Please Don't Go          AC/DC          NaN
# ...

# %%
df.dtypes
# Out:
# Song Clean      object
# ARTIST CLEAN    object
# Release Year    object
# COMBINED        object
# First?           int64
# Year?            int64
# PlayCount        int64
# F*G              int64
# dtype: object

# %%
df.describe()
# Out:
#        First?        Year?    PlayCount          F*G
# count  2230.0  2230.000000  2230.000000  2230.000000
# mean      1.0     0.741256    16.872646    15.048430
# std       0.0     0.438043    25.302972    25.288366
# min       1.0     0.000000     0.000000     0.000000
# 25%       1.0     0.000000     1.000000     0.000000
# 50%       1.0     1.000000     4.000000     3.000000
# 75%       1.0     1.000000    21.000000    18.000000
# max       1.0     1.000000   142.000000   142.000000

# %%
newdf = df[df['Year?'] > 0]

# %%
newdf
# Out:
#                                        Song Clean   ARTIST CLEAN Release Year  \
# 0                                Caught Up in You    .38 Special         1982
# 2                                 Hold On Loosely    .38 Special         1981
# 3                          Rockin' Into the Night    .38 Special         1980
# 4                               Art For Arts Sake           10cc         1975
# 5                                      Kryptonite   3 Doors Down         2000
# 6                                           Loser   3 Doors Down         2000
# 7                                   When I'm Gone   3 Doors Down         2002
# 8                                      What's Up?  4 Non Blondes         1992
# 9                                      Take On Me           a-ha         1985
# 11                                  Back In Black          AC/DC         1980
# 12                                        Big Gun          AC/DC         1993
# ...

# %%
newdf.head(2)
newdf.columns
# Out:
# Index([u'Song Clean', u'ARTIST CLEAN', u'Release Year', u'COMBINED', u'First?',
#        u'Year?', u'PlayCount', u'F*G'],
#       dtype='object')

# %%
# rynewdf = newdf['Release Year'].apply(int)


# Checking for non numeric in release year column
rynewdf = pd.to_numeric(newdf['Release Year'], errors='coerce')

# %%
rynewdf[rynewdf['Release Year'] > 1950].describe()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-137-72759f76e74a> in <module>()
# ----> 1 rynewdf[rynewdf['Release Year'] > 1950].describe()
#
# /Users/sebozek/anaconda/lib/python2.7/site-packages/pandas/core/series.pyc in __getitem__(self, key)
#     558     def __getitem__(self, key):
#     559         try:
# --> 560             result = self.index.get_value(self, key)
#     561
#     562             if not lib.isscalar(result):
#
# /Users/sebozek/anaconda/lib/python2.7/site-packages/pandas/indexes/base.pyc in get_value(self, series, key)
#    1909         try:
#    1910             return self._engine.get_value(s, k,
# -> 1911                                           tz=getattr(series.dtype, 'tz', None))
#    1912         except KeyError as e1:
#    1913             if len(self) > 0 and self.inferred_type in ['integer', 'boolean']:
#
# ...

# %%
newdf.get_dtype_counts()
# Out:
# int64     4
# object    4
# dtype: int64

# %%
if len(year) != 4
