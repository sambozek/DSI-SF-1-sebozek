# %%
import pandas as pd
import numpy as np
import scipy as sp
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
# Read in billboard.csv as a data frame, Try plotting your results!

pd.read_csv(../../assets/)

# %%
# The simplest pivot table must have a dataframe and an 
# index. Let’s use the artist as our index.
# Or attempt this using a groupby artist

# %%
# Let's look at the data by artist and track.  Try using a count or size aggregate.

# %%
# find out the number of weeks each song has been on the billboard

# %%
# add this as a new column

# %%
# make a new df with just weeks on billboard, artist, and track
